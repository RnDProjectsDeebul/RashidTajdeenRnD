# %%
import numpy as np
import pandas as pd
import os
import torch
from pathlib import Path
from torchvision.io import read_image
from torchvision.utils import make_grid
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
from torchvision import models, transforms
import torch.optim as optim
import cv2

# %%
class ImageDataset(Dataset):
    def __init__(self, csv_path, dataset_dir, train, test, transform=None, target_transform=None):
        
        self.img_csv = pd.read_csv(csv_path, usecols = ["ImgPath", "Distance"])
        self.dataset_dir = dataset_dir
        self.transform = transforms.Resize([128, 128])
        self.target_transform = (1./15.)


    def __len__(self):
        return len(self.img_csv)

    def __getitem__(self, idx):
        img_path = os.path.join(self.dataset_dir, self.img_csv.iloc[idx, 1])
        image = read_image(img_path)[:3,:,:]
        label = self.img_csv.iloc[idx, 0]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = label*self.target_transform
        return image, label

# %%
# image_dir = ""
# csv_path = "output/drone_dataset_28072022011417/data/drone.csv"

# %%
dataset_dir = "dataset/soccer_ball_07082022112157/"
csv_path = dataset_dir + "data/soccer_ball.csv"

# %%
# labels = pd.read_csv(csv_path, usecols = ["ImgPath", "Distance"]);

# %%
dataset = ImageDataset(csv_path, dataset_dir, train=True, test=False)
trainset,validset,testset = random_split(dataset,
                                         [int(len(dataset)*.65),int(len(dataset)*.15),int(len(dataset)*.20)],
                                         generator=torch.Generator().manual_seed(40))

trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
validloader = DataLoader(validset, batch_size=32, shuffle=True)
testloader = DataLoader(testset, batch_size=32, shuffle=True)

# %%
print(len(trainset))
print(trainset[0][0].size())
print(trainset[0][1])
# Out:
# 1300
# torch.Size([3, 128, 128])
# 0.6289320754704399

# %%
import torch
import torch.nn as nn
from torch.nn import functional

class Model(nn.Module):
    def __init__(self, freeze_resnet = False):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 2, 3, stride=1, padding=0)
        self.conv2 = nn.Conv2d(2, 1, 3, stride=1, padding=0)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(900, 300)
        self.fc2 = nn.Linear(300, 30)
        self.fc3 = nn.Linear(30, 1)

    def forward(self, x):
        x = self.pool(functional.relu(self.conv1(x)))
        x = self.pool(functional.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = functional.relu(self.fc1(x))
        x = functional.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def validation(model, validloader, criterion):
    
    val_loss = 0
    accuracy = 0
    
    for images, labels in iter(validloader):

#         images, labels = images.to('cuda'), labels.to('cuda')

        output = model.forward(images.type(torch.float))
        val_loss += criterion(output.type(torch.float), labels[:, None].type(torch.float)).item()
    
    return val_loss

# %%
# def train_classifier():
    
#     epochs = 100
#     steps = 0
#     print_every = 16
#     model_save_loc = "model/soccer_ball_07082022112157.pth"

# #     model.to('cuda')

#     for e in range(epochs):

#         model.train()

#         running_loss = 0

#         for images, labels in iter(trainloader):

#             steps += 1

# #             images, labels = images.to('cuda'), labels.to('cuda')

#             optimizer.zero_grad()
#             output = model.forward(images.float())
#             loss = criterion(output.float(), labels[:, None].float())
#             loss.backward()
#             optimizer.step()

#             running_loss += loss.item()

#             if steps % print_every == 0:

#                 model.eval()

#                 # Turn off gradients for validation, saves memory and computations
#                 with torch.no_grad():
#                     validation_loss = validation(model, validloader, criterion)

#                 print("Epoch: {}/{}.. ".format(e+1, epochs),
#                       "Training Loss: {:.3f}.. ".format(running_loss/print_every),
#                       "Validation Loss: {:.3f}.. ".format(validation_loss/len(validloader)))

#                 running_loss = 0
                
#                 torch.save(model, model_save_loc)
#                 model.train()

# %%
def train_classifier():
    
    epochs = 100
    last_loss = 10000
    patience = 3
    triggertimes = 0
    model_save_loc = "model/soccer_ball_07082022112157.pth"

#     model.to('cuda')

    for e in range(epochs):

        model.train()

        running_loss = 0

        for images, labels in iter(trainloader):

#             images, labels = images.to('cuda'), labels.to('cuda')

            optimizer.zero_grad()
            output = model.forward(images.float())
            loss = criterion(output.float(), labels[:, None].float())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()

        # Turn off gradients for validation, saves memory and computations
        with torch.no_grad():
            validation_loss = validation(model, validloader, criterion)

        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)),
              "Validation Loss: {:.3f}.. ".format(validation_loss/len(validloader)))
        
        current_loss = validation_loss
        print('The Current Loss:', current_loss)
        
        if current_loss > last_loss:
            trigger_times += 1
            print('Trigger Times:', trigger_times, '\n')
            
            if trigger_times >= patience:
                print('Early stopping!\nStart to test process.')
                return model
            
        else:
            print('trigger times: 0', '\n')
            trigger_times = 0
            torch.save(model, model_save_loc)
            
        last_loss = current_loss
        
        model.train()
    return model

# %%
model = models.resnet18(weights = 'DEFAULT')
model.fc = nn.Linear(in_features=512, out_features=1)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

res_model = train_classifier()
# Out:
# Epoch: 1/100..  Training Loss: 0.512..  Validation Loss: 0.039..
# The Current Loss: 0.3864260297268629
# trigger times: 0
#
# Epoch: 2/100..  Training Loss: 0.011..  Validation Loss: 0.007..
# The Current Loss: 0.06986568868160248
# trigger times: 0
#
# Epoch: 3/100..  Training Loss: 0.008..  Validation Loss: 0.005..
# The Current Loss: 0.048398497980087996
# trigger times: 0
#
# Epoch: 4/100..  Training Loss: 0.009..  Validation Loss: 0.010..
# The Current Loss: 0.09918448724783957
# Trigger Times: 1
#
# Epoch: 5/100..  Training Loss: 0.008..  Validation Loss: 0.003..
# The Current Loss: 0.02562899561598897
# trigger times: 0
#
# Epoch: 6/100..  Training Loss: 0.005..  Validation Loss: 0.002..
# The Current Loss: 0.02494082774501294
# trigger times: 0
#
# Epoch: 7/100..  Training Loss: 0.004..  Validation Loss: 0.003..
# The Current Loss: 0.027670504874549806
# Trigger Times: 1
#
# Epoch: 8/100..  Training Loss: 0.004..  Validation Loss: 0.003..
# The Current Loss: 0.03300269087776542
# Trigger Times: 2
#
# Epoch: 9/100..  Training Loss: 0.004..  Validation Loss: 0.003..
# The Current Loss: 0.02746877819299698
# trigger times: 0
#
# Epoch: 10/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.017992722219787538
# trigger times: 0
#
# Epoch: 11/100..  Training Loss: 0.003..  Validation Loss: 0.005..
# The Current Loss: 0.050863117328844965
# Trigger Times: 1
#
# Epoch: 12/100..  Training Loss: 0.005..  Validation Loss: 0.002..
# The Current Loss: 0.024398091016337276
# trigger times: 0
#
# Epoch: 13/100..  Training Loss: 0.005..  Validation Loss: 0.006..
# The Current Loss: 0.05992075754329562
# Trigger Times: 1
#
# Epoch: 14/100..  Training Loss: 0.006..  Validation Loss: 0.003..
# The Current Loss: 0.02736323536373675
# trigger times: 0
#
# Epoch: 15/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.016920577501878142
# trigger times: 0
#
# Epoch: 16/100..  Training Loss: 0.003..  Validation Loss: 0.003..
# The Current Loss: 0.031655871076509356
# Trigger Times: 1
#
# Epoch: 17/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.016288056212943047
# trigger times: 0
#
# Epoch: 18/100..  Training Loss: 0.004..  Validation Loss: 0.003..
# The Current Loss: 0.02767549455165863
# Trigger Times: 1
#
# Epoch: 19/100..  Training Loss: 0.004..  Validation Loss: 0.002..
# The Current Loss: 0.02010574657469988
# trigger times: 0
#
# Epoch: 20/100..  Training Loss: 0.003..  Validation Loss: 0.006..
# The Current Loss: 0.05748586426489055
# Trigger Times: 1
#
# Epoch: 21/100..  Training Loss: 0.004..  Validation Loss: 0.001..
# The Current Loss: 0.009656378970248625
# trigger times: 0
#
# Epoch: 22/100..  Training Loss: 0.005..  Validation Loss: 0.005..
# The Current Loss: 0.05271856649778783
# Trigger Times: 1
#
# Epoch: 23/100..  Training Loss: 0.005..  Validation Loss: 0.005..
# The Current Loss: 0.04635996278375387
# trigger times: 0
#
# Epoch: 24/100..  Training Loss: 0.006..  Validation Loss: 0.002..
# The Current Loss: 0.020745533052831888
# trigger times: 0
#
# Epoch: 25/100..  Training Loss: 0.003..  Validation Loss: 0.003..
# The Current Loss: 0.028902643593028188
# Trigger Times: 1
#
# Epoch: 26/100..  Training Loss: 0.003..  Validation Loss: 0.001..
# The Current Loss: 0.013941978162620217
# trigger times: 0
#
# Epoch: 27/100..  Training Loss: 0.004..  Validation Loss: 0.003..
# The Current Loss: 0.034690604195930064
# Trigger Times: 1
#
# Epoch: 28/100..  Training Loss: 0.003..  Validation Loss: 0.003..
# The Current Loss: 0.026226603775285184
# trigger times: 0
#
# Epoch: 29/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.01514852698892355
# trigger times: 0
#
# Epoch: 30/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.01977960718795657
# Trigger Times: 1
#
# Epoch: 31/100..  Training Loss: 0.003..  Validation Loss: 0.003..
# The Current Loss: 0.033280394854955375
# Trigger Times: 2
#
# Epoch: 32/100..  Training Loss: 0.002..  Validation Loss: 0.001..
# The Current Loss: 0.009316860523540527
# trigger times: 0
#
# Epoch: 33/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.02254108153283596
# Trigger Times: 1
#
# Epoch: 34/100..  Training Loss: 0.005..  Validation Loss: 0.001..
# The Current Loss: 0.011940164840780199
# trigger times: 0
#
# Epoch: 35/100..  Training Loss: 0.002..  Validation Loss: 0.001..
# The Current Loss: 0.009557751298416406
# trigger times: 0
#
# Epoch: 36/100..  Training Loss: 0.002..  Validation Loss: 0.003..
# The Current Loss: 0.025484233163297176
# Trigger Times: 1
#
# Epoch: 37/100..  Training Loss: 0.003..  Validation Loss: 0.001..
# The Current Loss: 0.012653980229515582
# trigger times: 0
#
# Epoch: 38/100..  Training Loss: 0.002..  Validation Loss: 0.005..
# The Current Loss: 0.054583864752203226
# Trigger Times: 1
#
# Epoch: 39/100..  Training Loss: 0.004..  Validation Loss: 0.002..
# The Current Loss: 0.01756079716142267
# trigger times: 0
#
# Epoch: 40/100..  Training Loss: 0.003..  Validation Loss: 0.007..
# The Current Loss: 0.06608777330256999
# Trigger Times: 1
#
# Epoch: 41/100..  Training Loss: 0.002..  Validation Loss: 0.003..
# The Current Loss: 0.028117012116126716
# trigger times: 0
#
# Epoch: 42/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.02059079031459987
# trigger times: 0
#
# Epoch: 43/100..  Training Loss: 0.002..  Validation Loss: 0.002..
# The Current Loss: 0.02023327152710408
# trigger times: 0
#
# Epoch: 44/100..  Training Loss: 0.003..  Validation Loss: 0.002..
# The Current Loss: 0.020231072790920734
# trigger times: 0
#
# Epoch: 45/100..  Training Loss: 0.002..  Validation Loss: 0.001..
# The Current Loss: 0.010540161922108382
# trigger times: 0
#
# Epoch: 46/100..  Training Loss: 0.002..  Validation Loss: 0.001..
# The Current Loss: 0.00868544916738756
# trigger times: 0
#
# Epoch: 47/100..  Training Loss: 0.002..  Validation Loss: 0.002..
# The Current Loss: 0.022477965452708304
# Trigger Times: 1
#
# Epoch: 48/100..  Training Loss: 0.002..  Validation Loss: 0.007..
# The Current Loss: 0.07196631096303463
# Trigger Times: 2
#
# Epoch: 49/100..  Training Loss: 0.002..  Validation Loss: 0.003..
# The Current Loss: 0.02968714409507811
# trigger times: 0
#
# Epoch: 50/100..  Training Loss: 0.002..  Validation Loss: 0.003..
# The Current Loss: 0.029092398413922638
# trigger times: 0
#
# Epoch: 51/100..  Training Loss: 0.002..  Validation Loss: 0.001..
# The Current Loss: 0.010133115865755826
# trigger times: 0
#
# Epoch: 52/100..  Training Loss: 0.002..  Validation Loss: 0.001..
# The Current Loss: 0.012265609635505825
# Trigger Times: 1
#
# Epoch: 53/100..  Training Loss: 0.001..  Validation Loss: 0.001..
# The Current Loss: 0.00966849472024478
# trigger times: 0
#
# Epoch: 54/100..  Training Loss: 0.001..  Validation Loss: 0.001..
# The Current Loss: 0.009064769008546136
# trigger times: 0
#
# Epoch: 55/100..  Training Loss: 0.001..  Validation Loss: 0.001..
# The Current Loss: 0.009569339541485533
# Trigger Times: 1
#
# Epoch: 56/100..  Training Loss: 0.001..  Validation Loss: 0.001..
# The Current Loss: 0.011616100498940796
# Trigger Times: 2
#
# Epoch: 57/100..  Training Loss: 0.002..  Validation Loss: 0.003..
# The Current Loss: 0.02651951613370329
# Trigger Times: 3
#
# Early stopping!
# Start to test process.

# %%
def test_accuracy(model, testloader):
    
    model.eval()
#     model.to('cuda')
    loss = 0

    with torch.no_grad():
    
        for images, labels in iter(testloader):
    
#             images, labels = images.to('cuda'), labels.to('cuda')
    
            output = model.forward(images.type(torch.float))
            loss += criterion(output.type(torch.float), labels[:, None].type(torch.float)).item()
        
        print("\nTest Loss: {}".format(loss))
        print("Average error in predicted distance: {}".format(loss*15))

# %%
test_model = torch.load("model/soccer_ball_07082022112157.pth")
test_accuracy(test_model, testloader)
# Out:
# Test Loss: 0.018067445082124323
# Average error in predicted distance: 0.27101167623186484
